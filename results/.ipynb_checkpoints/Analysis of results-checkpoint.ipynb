# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
path = "length_gravity_v0.csv"

# %%
df3 = pd.read_csv(path)
col = ["Task#","Seed", "Gravity", "Length", "Force_mag", "Episode", "Score"]
df3 = df3[col]
df_gb = df3.groupby(["Task#", "Gravity", "Length", "Force_mag","Episode"]).mean().reset_index()

df_gb2 = df3[["Task#", "Gravity", "Length", "Force_mag","Score"]].groupby(["Task#", "Gravity", "Length", "Force_mag"]).aggregate(lambda x: list(x))#.reset_index()
print(df_gb2)
offset = 0
colors = ["r", "b", "g","y"]
fig, ax = plt.subplots(1,1,figsize= (15,5))
for i in range(4):
    values = df_gb2.values[i][0]
    l = len(values)
    plt.plot(list(np.array([i for i in range(1,l+1)])+offset), values, colors[i])
    offset+= l
plt.axhline(200,color= "black")
plt.title("DQN score for a few tasks")
plt.xlabel("Episode")
plt.ylabel("Score")
plt.ylim((0,500))
plt.show()
# Out:
#                                                                             Score
# Task# Gravity Length Force_mag
# 0     1       9.8    10.0       [43.0, 16.0, 33.0, 36.0, 72.0, 33.0, 23.0, 16....
# 1     1       2.0    10.0       [70.0, 37.0, 25.0, 29.0, 18.0, 57.0, 25.0, 44....
# 2     10      9.8    10.0       [106.0, 100.0, 65.0, 68.0, 80.0, 137.0, 62.0, ...
# 3     10      2.0    10.0       [142.0, 122.0, 193.0, 65.0, 109.0, 196.0, 171....

# %%
offset = 0
plt.clf()

fig , ax = plt.subplots(1, len(params), figsize=(20,10))
#concatenated_score = []
#concatenated_index = []
for task_id, score in enumerate(scores):
    #concatenated_score += score
    #concatenated_index += list(np.array([i for i in range(len(score))]) + offset)
    episode = np.array([i for i in range(len(score))])
    offseted_episode = list(episode + offset)
    ax[task_id].plot(episode, score)
    offset += len(score)
    ax[task_id].set_ylim([0,300])
    ax[task_id].set_title("Task n°{} (Length: {})".format(task_id, params[task_id]))
ax[0].set_ylabel("Score")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-6029510c4517> in <module>
#       2 plt.clf()
#       3
# ----> 4 fig , ax = plt.subplots(1, len(params), figsize=(20,10))
#       5 #concatenated_score = []
#       6 #concatenated_index = []
#
# NameError: name 'params' is not defined
